# %%
import yfinance as yf
import pandas as pd

# List of stocks
stocks = ['AAPL', 'MSFT', 'CMCSA', 'COST', 'QCOM', 'ADBE', 'SBUX', 'INTU', 'AMD', 'INTC']

# Download historical data for both 'Close' and 'Volume'
data = yf.download(stocks, start="2015-01-01", end="2023-12-31")['Close']

# Save to CSV
data.to_csv('stock_data.csv')

print("Data downloaded and saved to 'stock_data.csv'")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  10 of 10 completed
# Data downloaded and saved to 'stock_data.csv'

# %%
from sklearn.preprocessing import MinMaxScaler

# Load data
data = pd.read_csv('stock_data.csv', index_col='Date', parse_dates=True)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Convert back to DataFrame
scaled_data = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_datareader) (5.3.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.23->pandas_datareader) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.23->pandas_datareader) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.23->pandas_datareader) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pandas_datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pandas_datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pandas_datareader.data as web
import datetime

# Define the date range
start_date = datetime.datetime(2015, 1, 1)
end_date = datetime.datetime(2023, 12, 31)

# List of macroeconomic indicators (FRED series codes)
indicators = {
    'GDP': 'GDP',  # Gross Domestic Product
    'UNRATE': 'UNRATE',  # Unemployment Rate
    'CPIAUCSL': 'CPIAUCSL',  # Consumer Price Index (CPI)
    'FEDFUNDS': 'FEDFUNDS',  # Federal Funds Rate
    'INDPRO': 'INDPRO',  # Industrial Production Index
    'UMCSENT': 'UMCSENT',  # University of Michigan Consumer Sentiment Index
}

# Fetch macroeconomic data from FRED
macro_data = pd.DataFrame()

for name, code in indicators.items():
    macro_data[name] = web.DataReader(code, 'fred', start_date, end_date)

# Forward fill missing values (since some indicators are reported monthly or quarterly)
macro_data = macro_data.ffill()

# Save to CSV
macro_data.to_csv('macroeconomic_data.csv')

print("Macroeconomic data downloaded and saved to 'macroeconomic_data.csv'")
# Out:
# Macroeconomic data downloaded and saved to 'macroeconomic_data.csv'

# %%
from sklearn.preprocessing import MinMaxScaler
# Load macroeconomic data
macro_data = pd.read_csv('macroeconomic_data.csv', index_col='DATE', parse_dates=True)

# Forward fill missing values (since some indicators are reported monthly or quarterly)
macro_data = macro_data.ffill()

# Normalize macroeconomic data
macro_scaler = MinMaxScaler(feature_range=(0, 1))
scaled_macro_data = macro_scaler.fit_transform(macro_data)
scaled_macro_data = pd.DataFrame(scaled_macro_data, columns=macro_data.columns, index=macro_data.index)

# Align macroeconomic data with stock data
scaled_macro_data = scaled_macro_data.reindex(data.index, method='ffill')  # Align dates with stock data

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)  # Reduce to 3 components
macro_pca = pca.fit_transform(scaled_macro_data)

# Convert back to DataFrame
macro_pca_df = pd.DataFrame(macro_pca, index=scaled_macro_data.index, columns=['PC1', 'PC2', 'PC3'])

# Replace macro data with PCA-transformed data
scaled_macro_data = macro_pca_df

# %%
data.head()
# Out:
#                  AAPL       ADBE   AMD      CMCSA        COST       INTC  \
# Date
# 2015-01-02  24.320438  72.339996  2.67  22.698528  114.605011  27.896454
# 2015-01-05  23.635290  71.980003  2.66  22.235615  113.302010  27.581900
# 2015-01-06  23.637512  70.529999  2.63  21.945557  114.799240  27.067852
# 2015-01-07  23.968958  71.110001  2.58  21.925688  116.798203  27.635601
# 2015-01-08  24.889900  72.919998  2.61  22.402504  117.801758  28.149639
#
#                  INTU       MSFT       QCOM       SBUX
# Date
# 2015-01-02  83.803795  40.072128  55.253315  33.345455
# 2015-01-05  83.473007  39.703640  54.992981  32.706696
# 2015-01-06  80.909561  39.120911  54.211899  32.440575
# 2015-01-07  81.701965  39.617939  54.844200  33.238995
# 2015-01-08  82.798470  40.783428  55.424393  33.775360

# %%
scaled_data.head()
# Out:
#                 AAPL      ADBE       AMD     CMCSA      COST      INTC  \
# Date
# 2015-01-02  0.020686  0.003800  0.006551  0.045926  0.005028  0.181759
# 2015-01-05  0.016798  0.003218  0.006488  0.032466  0.002661  0.174230
# 2015-01-06  0.016811  0.000873  0.006301  0.024032  0.005381  0.161927
# 2015-01-07  0.018691  0.001811  0.005989  0.023454  0.009013  0.175515
# 2015-01-08  0.023917  0.004738  0.006176  0.037319  0.010837  0.187818
#
#                 INTU      MSFT      QCOM      SBUX
# Date
# 2015-01-02  0.016234  0.015822  0.155841  0.010836
# 2015-01-05  0.015688  0.014752  0.154022  0.003187
# 2015-01-06  0.011460  0.013061  0.148561  0.000000
# 2015-01-07  0.012767  0.014504  0.152982  0.009561
# 2015-01-08  0.014576  0.017887  0.157037  0.015983

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Concatenate stock data and macroeconomic data
combined_data = pd.concat([scaled_data, scaled_macro_data], axis=1)

# Create sequences for the combined data
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data.iloc[i:(i + seq_length)].values
        y = data.iloc[i + seq_length].values[:len(stocks)]  # Target is still stock prices
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

seq_length = 21
X_combined, y = create_sequences(combined_data, seq_length)

# Convert to PyTorch tensors
X_combined_train = torch.tensor(X_combined, dtype=torch.float32)
y_train = torch.tensor(y, dtype=torch.float32)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob=0.5):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout_prob)
        self.fc = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_prob)  # Additional dropout layer after LSTM

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])  # Apply dropout to the output of the LSTM
        out = self.fc(out)
        return out

# Define LSTM model
# Update input size for LSTM
input_size = X_combined_train.shape[2]  # Number of features (stock prices + macroeconomic indicators)
hidden_size = 50
num_layers = 2
output_size = y_train.shape[1]

lstm_model = LSTM(input_size, hidden_size, num_layers, output_size)

# %%
criterion = nn.MSELoss()
optimizer_lstm = optim.Adam(lstm_model.parameters(), lr=0.001)

criterion = nn.MSELoss()
optimizer_lstm = optim.Adam(lstm_model.parameters(), lr=0.001)

for epoch in range(50):
    lstm_model.train()
    optimizer_lstm.zero_grad()

    lstm_outputs = lstm_model(X_combined_train)
    loss_lstm = criterion(lstm_outputs, y_train)

    loss_lstm.backward()
    optimizer_lstm.step()

    if (epoch + 1) % 10 == 0:
        print(f'LSTM Epoch [{epoch+1}/50], Loss: {loss_lstm.item():.6f}')
# Out:
# LSTM Epoch [10/50], Loss: 0.157766
# LSTM Epoch [20/50], Loss: 0.069447
# LSTM Epoch [30/50], Loss: 0.043965
# LSTM Epoch [40/50], Loss: 0.034760
# LSTM Epoch [50/50], Loss: 0.030950

# %%
corr_matrix = data.corr()
print(corr_matrix)
# Out:
#            AAPL      ADBE       AMD     CMCSA      COST      INTC      INTU  \
# AAPL   1.000000  0.883235  0.966217  0.734230  0.980906  0.335356  0.954418
# ADBE   0.883235  1.000000  0.938067  0.898509  0.864104  0.665857  0.949287
# AMD    0.966217  0.938067  1.000000  0.812524  0.947782  0.458076  0.970326
# CMCSA  0.734230  0.898509  0.812524  1.000000  0.705129  0.711814  0.829652
# COST   0.980906  0.864104  0.947782  0.705129  1.000000  0.333091  0.956215
# INTC   0.335356  0.665857  0.458076  0.711814  0.333091  1.000000  0.490478
# INTU   0.954418  0.949287  0.970326  0.829652  0.956215  0.490478  1.000000
# MSFT   0.984688  0.932205  0.978074  0.790987  0.978067  0.441588  0.979547
# QCOM   0.933886  0.885738  0.953695  0.798148  0.907933  0.437437  0.928852
# SBUX   0.879054  0.896675  0.893729  0.861208  0.869243  0.493041  0.921208
#
#            MSFT      QCOM      SBUX
# AAPL   0.984688  0.933886  0.879054
# ADBE   0.932205  0.885738  0.896675
# AMD    0.978074  0.953695  0.893729
# CMCSA  0.790987  0.798148  0.861208
# COST   0.978067  0.907933  0.869243
# INTC   0.441588  0.437437  0.493041
# INTU   0.979547  0.928852  0.921208
# MSFT   1.000000  0.921976  0.909237
# QCOM   0.921976  1.000000  0.878131
# SBUX   0.909237  0.878131  1.000000

# %%
import torch
# !pip install torch-geometric
import torch_geometric
from torch_geometric.nn import GCNConv
# Install mlxtend if you haven't
# !pip install mlxtend

# Import necessary functions
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import torch
from torch_geometric.nn import GCNConv
from mlxtend.frequent_patterns import apriori, association_rules

def construct_dynamic_graph(data, stocks, corr_threshold=0.6, min_support=0.1, lift_threshold=1.5):
    """
    Constructs a dynamic graph using Pearson correlation and association rules.

    Args:
        data (pd.DataFrame): DataFrame containing stock prices (columns = stock names).
        stocks (list): List of stock names (column names of `data`).
        corr_threshold (float): Threshold for Pearson correlation.
        min_support (float): Minimum support for the Apriori algorithm.
        lift_threshold (float): Minimum lift for association rules.

    Returns:
        edge_index (torch.Tensor): Tensor of edge indices for the graph.
        edge_weights (torch.Tensor): Tensor of edge weights.
    """
    import pandas as pd
    from mlxtend.frequent_patterns import apriori, association_rules

    # Compute correlation matrix
    corr_matrix = data.corr()

    edges, edge_weights = [], []

    # Pearson correlation-based edges
    for i in range(len(stocks)):
        for j in range(i + 1, len(stocks)):
            corr_value = corr_matrix.iloc[i, j]
            if abs(corr_value) > corr_threshold:
                edges.append([i, j])
                edge_weights.append(corr_value)

    # Association rule-based edges
    stock_movements = (data.pct_change().dropna() > 0)
    frequent_itemsets = apriori(stock_movements, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=lift_threshold)

    for _, rule in rules.iterrows():
        try:
            i = stocks.index(next(iter(rule['antecedents'])))
            j = stocks.index(next(iter(rule['consequents'])))
            edges.append([i, j])
            edge_weights.append(rule['lift'])
        except (StopIteration, ValueError):
            continue  # Skip rules with invalid stocks

    if len(edges) == 0:
        # Avoid empty tensor creation if no edges found
        return torch.empty((2, 0), dtype=torch.long), torch.empty((0,), dtype=torch.float32)

    edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
    edge_weights = torch.tensor(edge_weights, dtype=torch.float32)

    return edge_index, edge_weights
# Out:
# Requirement already satisfied: torch-geometric in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.6.1)
# Requirement already satisfied: aiohttp in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (3.11.13)
# Requirement already satisfied: fsspec in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (2.2.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (7.0.0)
# Requirement already satisfied: pyparsing in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (3.2.1)
# Requirement already satisfied: requests in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torch-geometric) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torch-geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torch-geometric) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torch-geometric) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->torch-geometric) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: mlxtend in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
class GNN(nn.Module):
    def __init__(self, num_features, hidden_size, num_classes, dropout_prob=0.5):
        super(GNN, self).__init__()
        self.conv1 = GCNConv(num_features, hidden_size)
        self.conv2 = GCNConv(hidden_size, num_classes)
        self.dropout = nn.Dropout(dropout_prob)  # Dropout layer

    def forward(self, x, edge_index, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight)
        x = torch.relu(x)
        x = self.dropout(x)  # Apply dropout after the first GCN layer
        x = self.conv2(x, edge_index, edge_weight)
        return x


# 🔹 Compute stock returns (used as node features for GNN)
returns = data.pct_change().dropna().values  # Shape: (num_samples, num_stocks)

# 🔹 Define GNN model
num_features = returns.shape[1]  # Each stock is a node, features = num_stocks
hidden_size = 16
gnn_output_size = num_features  # Output should match the number of stocks

gnn_model = GNN(num_features, hidden_size, gnn_output_size)

# 🔹 Convert stock returns to PyTorch tensor (used as GNN input)
X_gnn_train = torch.tensor(returns, dtype=torch.float32)  # Shape: (num_samples, num_stocks)

# 🔹 Define target labels (future stock returns for supervised learning)
y_train_gnn = torch.tensor(data.pct_change().shift(-1).dropna().values, dtype=torch.float32)

# 🔹 Ensure `y_train_gnn` is correctly aligned with `X_gnn_train`
y_train_gnn = y_train_gnn[:X_gnn_train.shape[0], :]  # Trim to match `X_gnn_train`

# %%
class HybridModel(nn.Module):
    def __init__(self, lstm_model, gnn_model, lstm_output_size, gnn_output_size, final_output_size):
        super(HybridModel, self).__init__()
        self.lstm_model = lstm_model
        self.gnn_model = gnn_model
        self.fc = nn.Linear(lstm_output_size + gnn_output_size, final_output_size)

    def forward(self, x_lstm, x_gnn, edge_index):
        lstm_out = self.lstm_model(x_lstm)  # Shape: (batch_size, lstm_output_size)
        gnn_out = self.gnn_model(x_gnn, edge_index)  # Shape: (num_nodes, gnn_output_size)

        # Trim the GNN output to match the LSTM batch size
        gnn_out_trimmed = gnn_out[:x_lstm.size(0), :]  # Shape: (batch_size, gnn_output_size)

        # Concatenate LSTM and GNN outputs
        combined = torch.cat((lstm_out, gnn_out_trimmed), dim=1)  # Shape: (batch_size, lstm_output_size + gnn_output_size)

        # Pass through the fully connected layer
        out = self.fc(combined)  # Shape: (batch_size, final_output_size)
        return out

# %%
lstm_output_size = 10  # Example, change based on your LSTM output
gnn_output_size = 10   # Example, change based on your GNN output
final_output_size = 10  # Output size of the final prediction

# Instantiate the Hybrid Model with correct arguments

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd




# Initialize model
hybrid_model = HybridModel(lstm_model, gnn_model, lstm_output_size, gnn_output_size, final_output_size)

"""def save_model(model, path=model_path):
    torch.save(model.state_dict(), path)
    print(f"Model saved to {path}")

def load_model(model, path=model_path):
    if os.path.exists(path):
        model.load_state_dict(torch.load(path))
        print("Model loaded successfully from Google Drive.")
    else:
        print("No saved model found, training from scratch.")

"""
mse_file = "mse_log.xlsx"  # You can change this to any desired path


def adjust_edge_index_for_batch(edge_index, batch_size):
    mask = (edge_index < batch_size).all(dim=0)
    return edge_index[:, mask]

print(f"X_lstm_train shape: {X_combined_train}")
print(f"X_gnn_train shape: {X_gnn_train.shape}")
print(f"y_train shape: {y_train.shape}")

def expanding_window_training(X_combined, X_gnn, y, model,  seq_length=21, epochs=50):
    """Train the model using an expanding window approach with model saving/loading."""
    #load_model(model, model_path)  # Load existing model if available

    train_size = int(len(X_combined) * 0.8)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.005)

    mse_data = []  # Store MSE values

    for i in range(train_size, len(X_combined) - seq_length):
        X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
        X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
        y_train = torch.tensor(y[:i], dtype=torch.float32)
        # Construct edge_index dynamically using current window
        window_df = pd.DataFrame(X_gnn[:i], columns=stocks)  # Reconstruct the window DataFrame
        edge_index, edge_weights = construct_dynamic_graph(window_df, stocks)
        batch_size = X_combined_train.size(0)
        adjusted_edge_index = adjust_edge_index_for_batch(edge_index, batch_size)

        model.train()
        for epoch in range(epochs):
            optimizer.zero_grad()
            predictions = model(X_combined_train, X_gnn_train, adjusted_edge_index)
            loss = criterion(predictions, y_train)
            loss.backward()
            optimizer.step()

            if (epoch + 1) % 10 == 0:
                print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.6f}")

        # Test on next step
        model.eval()
        with torch.no_grad():
            X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
            X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
            y_test = torch.tensor(y[i:i+1], dtype=torch.float32)

            test_batch_size = X_combined_test.size(0)
            adjusted_edge_index_test = adjust_edge_index_for_batch(edge_index, test_batch_size)

            predictions_test = model(X_combined_test, X_gnn_test, adjusted_edge_index_test)
            mse = criterion(predictions_test, y_test).item()
            print(f"Day {i+1}, Test MSE: {mse:.6f}")

            mse_data.append([i+1, mse])

    #save_model(model, model_path)  # Save the trained model

    # Save MSE values to an Excel file
    mse_df = pd.DataFrame(mse_data, columns=["Day", "MSE"])
    mse_df.to_excel(mse_file, index=False)
    print(f"MSE log saved to {mse_file}")

# Call the function with combined data
expanding_window_training(X_combined_train, X_gnn_train, y_train, hybrid_model,  seq_length=21, epochs=50)
# Out:
# X_lstm_train shape: tensor([[[ 2.0686e-02,  3.8002e-03,  6.5506e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 1.6798e-02,  3.2181e-03,  6.4882e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 1.6811e-02,  8.7325e-04,  6.3011e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          ...,
#          [ 3.2764e-02,  2.6683e-03,  6.1763e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.0568e-02,  2.2640e-04,  5.9268e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.2423e-02,  1.8112e-03,  6.5506e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02]],
#
#         [[ 1.6798e-02,  3.2181e-03,  6.4882e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 1.6811e-02,  8.7325e-04,  6.3011e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 1.8691e-02,  1.8112e-03,  5.9891e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          ...,
#          [ 3.0568e-02,  2.2640e-04,  5.9268e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.2423e-02,  1.8112e-03,  6.5506e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.2448e-02,  3.1211e-03,  7.1121e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02]],
#
#         [[ 1.6811e-02,  8.7325e-04,  6.3011e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 1.8691e-02,  1.8112e-03,  5.9891e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 2.3917e-02,  4.7382e-03,  6.1763e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          ...,
#          [ 3.2423e-02,  1.8112e-03,  6.5506e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.2448e-02,  3.1211e-03,  7.1121e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02],
#          [ 3.3597e-02,  3.7032e-03,  7.6736e-03,  ..., -6.2148e-01,
#           -9.7454e-02, -6.7069e-02]],
#
#         ...,
#
#         [[ 9.5308e-01,  8.8826e-01,  7.5507e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.5652e-01,  8.9481e-01,  7.5108e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.5071e-01,  8.8522e-01,  7.6256e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          ...,
#          [ 9.8066e-01,  8.5732e-01,  8.6275e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7456e-01,  8.5507e-01,  8.6081e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7146e-01,  8.5428e-01,  8.8458e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01]],
#
#         [[ 9.5652e-01,  8.9481e-01,  7.5108e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.5071e-01,  8.8522e-01,  7.6256e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.5398e-01,  8.7490e-01,  7.4577e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          ...,
#          [ 9.7456e-01,  8.5507e-01,  8.6081e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7146e-01,  8.5428e-01,  8.8458e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7203e-01,  8.5076e-01,  9.0118e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01]],
#
#         [[ 9.5071e-01,  8.8522e-01,  7.6256e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.5398e-01,  8.7490e-01,  7.4577e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.6125e-01,  8.7726e-01,  7.4721e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          ...,
#          [ 9.7146e-01,  8.5428e-01,  8.8458e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7203e-01,  8.5076e-01,  9.0118e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01],
#          [ 9.7445e-01,  8.4985e-01,  9.1796e-01,  ...,  1.2116e+00,
#           -1.5609e-01,  2.5454e-01]]])
# X_gnn_train shape: torch.Size([2263, 10])
# y_train shape: torch.Size([2243, 10])
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.047175
# Epoch [20/50], Loss: 0.017003
# Epoch [30/50], Loss: 0.011566
# Epoch [40/50], Loss: 0.008876
# Epoch [50/50], Loss: 0.007820
# Day 1795, Test MSE: 0.015383
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.006893
# Epoch [20/50], Loss: 0.006284
# Epoch [30/50], Loss: 0.005654
# Epoch [40/50], Loss: 0.005262
# Epoch [50/50], Loss: 0.004848
# Day 1796, Test MSE: 0.008912
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.004721
# Epoch [20/50], Loss: 0.004422
# Epoch [30/50], Loss: 0.004187
# Epoch [40/50], Loss: 0.004050
# Epoch [50/50], Loss: 0.003917
# Day 1797, Test MSE: 0.006606
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003816
# Epoch [20/50], Loss: 0.003850
# Epoch [30/50], Loss: 0.003777
# Epoch [40/50], Loss: 0.003719
# Epoch [50/50], Loss: 0.003661
# Day 1798, Test MSE: 0.007789
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003427
# Epoch [20/50], Loss: 0.003517
# Epoch [30/50], Loss: 0.003557
# Epoch [40/50], Loss: 0.003520
# Epoch [50/50], Loss: 0.003410
# Day 1799, Test MSE: 0.008095
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003402
# Epoch [20/50], Loss: 0.003424
# Epoch [30/50], Loss: 0.003332
# Epoch [40/50], Loss: 0.003317
# Epoch [50/50], Loss: 0.003171
# Day 1800, Test MSE: 0.008160
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003244
# Epoch [20/50], Loss: 0.003347
# Epoch [30/50], Loss: 0.003314
# Epoch [40/50], Loss: 0.003155
# Epoch [50/50], Loss: 0.003175
# Day 1801, Test MSE: 0.006741
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003035
# Epoch [20/50], Loss: 0.003228
# Epoch [30/50], Loss: 0.003097
# Epoch [40/50], Loss: 0.003132
# Epoch [50/50], Loss: 0.003239
# Day 1802, Test MSE: 0.005578
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003034
# Epoch [20/50], Loss: 0.003054
# Epoch [30/50], Loss: 0.002993
# Epoch [40/50], Loss: 0.003031
# Epoch [50/50], Loss: 0.003073
# Day 1803, Test MSE: 0.005750
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003040
# Epoch [20/50], Loss: 0.003112
# Epoch [30/50], Loss: 0.003072
# Epoch [40/50], Loss: 0.003022
# Epoch [50/50], Loss: 0.003050
# Day 1804, Test MSE: 0.004445
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003012
# Epoch [20/50], Loss: 0.003172
# Epoch [30/50], Loss: 0.003125
# Epoch [40/50], Loss: 0.003019
# Epoch [50/50], Loss: 0.002975
# Day 1805, Test MSE: 0.005205
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003132
# Epoch [20/50], Loss: 0.003102
# Epoch [30/50], Loss: 0.002866
# Epoch [40/50], Loss: 0.002974
# Epoch [50/50], Loss: 0.003061
# Day 1806, Test MSE: 0.005417
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002902
# Epoch [20/50], Loss: 0.003064
# Epoch [30/50], Loss: 0.003100
# Epoch [40/50], Loss: 0.003030
# Epoch [50/50], Loss: 0.002889
# Day 1807, Test MSE: 0.006509
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002976
# Epoch [20/50], Loss: 0.002910
# Epoch [30/50], Loss: 0.002920
# Epoch [40/50], Loss: 0.003144
# Epoch [50/50], Loss: 0.003106
# Day 1808, Test MSE: 0.007160
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002900
# Epoch [20/50], Loss: 0.003036
# Epoch [30/50], Loss: 0.003007
# Epoch [40/50], Loss: 0.002895
# Epoch [50/50], Loss: 0.002949
# Day 1809, Test MSE: 0.008796
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002885
# Epoch [20/50], Loss: 0.003080
# Epoch [30/50], Loss: 0.002907
# Epoch [40/50], Loss: 0.002936
# Epoch [50/50], Loss: 0.003026
# Day 1810, Test MSE: 0.008141
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002996
# Epoch [20/50], Loss: 0.003295
# Epoch [30/50], Loss: 0.003000
# Epoch [40/50], Loss: 0.003027
# Epoch [50/50], Loss: 0.003009
# Day 1811, Test MSE: 0.006470
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002826
# Epoch [20/50], Loss: 0.002993
# Epoch [30/50], Loss: 0.002919
# Epoch [40/50], Loss: 0.002894
# Epoch [50/50], Loss: 0.002981
# Day 1812, Test MSE: 0.007169
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003038
# Epoch [20/50], Loss: 0.003056
# Epoch [30/50], Loss: 0.002912
# Epoch [40/50], Loss: 0.002898
# Epoch [50/50], Loss: 0.002910
# Day 1813, Test MSE: 0.006163
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003010
# Epoch [20/50], Loss: 0.002957
# Epoch [30/50], Loss: 0.002904
# Epoch [40/50], Loss: 0.003016
# Epoch [50/50], Loss: 0.003038
# Day 1814, Test MSE: 0.006664
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.002888
# Epoch [20/50], Loss: 0.003068
# Epoch [30/50], Loss: 0.002772
# Epoch [40/50], Loss: 0.003105
# Epoch [50/50], Loss: 0.002983
# Day 1815, Test MSE: 0.004904
# ...
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003837
# Epoch [20/50], Loss: 0.003581
# Epoch [30/50], Loss: 0.003811
# Epoch [40/50], Loss: 0.003674
# Epoch [50/50], Loss: 0.003818
# Day 2216, Test MSE: 0.003066
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.004073
# Epoch [20/50], Loss: 0.003786
# Epoch [30/50], Loss: 0.003909
# Epoch [40/50], Loss: 0.003748
# Epoch [50/50], Loss: 0.003718
# Day 2217, Test MSE: 0.001863
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003772
# Epoch [20/50], Loss: 0.003829
# Epoch [30/50], Loss: 0.003830
# Epoch [40/50], Loss: 0.003816
# Epoch [50/50], Loss: 0.003660
# Day 2218, Test MSE: 0.001931
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003779
# Epoch [20/50], Loss: 0.003736
# Epoch [30/50], Loss: 0.003748
# Epoch [40/50], Loss: 0.003935
# Epoch [50/50], Loss: 0.003773
# Day 2219, Test MSE: 0.002033
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003820
# Epoch [20/50], Loss: 0.003817
# Epoch [30/50], Loss: 0.003766
# Epoch [40/50], Loss: 0.003856
# Epoch [50/50], Loss: 0.003877
# Day 2220, Test MSE: 0.002292
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003807
# Epoch [20/50], Loss: 0.003791
# Epoch [30/50], Loss: 0.003766
# Epoch [40/50], Loss: 0.003799
# Epoch [50/50], Loss: 0.003909
# Day 2221, Test MSE: 0.003896
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_train = torch.tensor(X_combined[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_train = torch.tensor(X_gnn[:i], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y[:i], dtype=torch.float32)
# Epoch [10/50], Loss: 0.003880
# Epoch [20/50], Loss: 0.003727
# Epoch [30/50], Loss: 0.003777
# Epoch [40/50], Loss: 0.003775
# Epoch [50/50], Loss: 0.003830
# Day 2222, Test MSE: 0.002534
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_combined_test = torch.tensor(X_combined[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_gnn_test = torch.tensor(X_gnn[i:i+1], dtype=torch.float32)
# C:\Users\Karim\AppData\Local\Temp\ipykernel_17152\3558717691.py:72: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y[i:i+1], dtype=torch.float32)
# MSE log saved to mse_log.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load MSE values from the Excel file
mse_data = pd.read_excel(mse_file)

# Calculate the overall average MSE
overall_avg_mse = mse_data["MSE"].mean()

# Plot MSE
plt.figure(figsize=(10, 5))
plt.plot(mse_data["Day"], mse_data["MSE"], marker="o", linestyle="-", color="b", label="Test MSE")

# Add a horizontal line for the overall average MSE
plt.axhline(y=overall_avg_mse, color="r", linestyle="--", label=f"Avg MSE: {overall_avg_mse:.6f}")

# Labels and title
plt.xlabel("Day")
plt.ylabel("Mean Squared Error (MSE)")
plt.title("Test MSE Over Training Days")
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# Print the overall average MSE
print(f"Overall Average MSE: {overall_avg_mse:.6f}")
# Out:
# Overall Average MSE: 0.002465
